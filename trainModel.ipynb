# %%
# Useful libraries
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision

import matplotlib.pyplot as plt
from torchvision import datasets, models, transforms
from torch.utils.data import TensorDataset
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt

from torch.cuda import is_available

# %%
class SLR(nn.Module):
    def __init__(self):
        self.name = "SLR"
        super(SLR, self).__init__()
        self.fc1 = nn.Linear(256*6*6, 200)
        self.fc2 = nn.Linear(200, 80)
        self.fc3 = nn.Linear(80,10)
        self.DropOut = nn.Dropout(0.2)
        
    def forward(self,x):
        x = x.view(-1,256*6*6)
        x = self.DropOut(x)
        x = F.relu(self.fc1(x))
        x = self.DropOut(x)
        x = F.relu(self.fc2(x))
        x = self.DropOut(x)
        x = self.fc3(x)
        return x

# %%
path = 'dataset/'

train_set_features = torchvision.datasets.DatasetFolder(path + 'TrainFeatures', loader=torch.load, extensions=('.tensor'))
valid_set_features = torchvision.datasets.DatasetFolder(path + 'ValidFeatures', loader=torch.load, extensions=('.tensor'))
test_set_features = torchvision.datasets.DatasetFolder(path + 'TestFeatures', loader=torch.load, extensions=('.tensor'))
print("train set size: ", len(train_set_features))
print("validation set size: ", len(valid_set_features))
print("test set size: ", len(test_set_features))
# Out:
# train set size:  3892
# validation set size:  485
# test set size:  489

# %%
# function to calculate accuracy
def get_accuracy(model, train_loader, valid_loader, train=False):
    if train:
        data = train_loader
    else:
        data = valid_loader

    correct = 0
    total = 0
    for imgs, labels in data:
        
        #enable GPU Usage
        if torch.cuda.is_available():
          imgs = imgs.cuda()
          labels = labels.cuda()

        output = model(imgs)
        
        #select index with maximum prediction score
        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()
        total += imgs.shape[0]
    return correct / total

def get_test_accuracy(model, test_loader):
    data = test_loader
    correct = 0
    total = 0
    
    for imgs, labels in data:
        if torch.cuda.is_available():
            imgs = imgs.cuda()
            labels = labels.cuda()
            
        output = model(imgs)
    
        #select index with maximum prediction score
        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()
        total += imgs.shape[0]
    return correct/total

# %%
from torch.cuda import is_available
def train(model, train_set, valid_set, batch_size=50, learning_rate=0.001,beta1=0.9, beta2=0.999, eps=1e-8, num_epochs=1):
  
  print("Loading data...")
  #load data
  train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle= True)
  valid_loader = torch.utils.data.DataLoader(valid_set, batch_size=batch_size, shuffle= True)
  
  #Cross Entropy Loss and SGD optimizer
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(model.parameters(), lr=learning_rate, betas=(beta1,beta2), eps=eps)

  iters, losses, train_acc, valid_acc = [],[],[],[]
  print("Starting training...")
  #training
  n = 0 # of iterations
  for epoch in range(num_epochs):
    for imgs, labels in iter(train_loader):

      #enable GPU
      if torch.cuda.is_available():
        imgs = imgs.cuda()
        labels = labels.cuda()

      out = model(imgs)  #forward pass
      loss = criterion(out, labels) #compute total loss
      loss.backward() #backward pass and parameter update
      optimizer.step() #make the updates for each parameter
      optimizer.zero_grad() #clean up

      #save training information
      iters.append(n)
      losses.append(float(loss)/batch_size) #compute "average" loss
      train_acc.append(get_accuracy(model,train_loader,valid_loader,train=True))
      valid_acc.append(get_accuracy(model,train_loader,valid_loader,train=False))
      if n%10 == 0:
        print("Iter number ",n, " train accuracy: ",train_acc[n], " valid accuracy: ",valid_acc[n])
      n+=1
      
    #save model

    model_path = "TrainingModel/model_{0}_bs{1}_lr{2}_epoch{3}".format(model.name, batch_size, learning_rate, epoch)
    torch.save(model.state_dict(), model_path)
    print("epoch: ", epoch)

  plt.title("Training Curve")
  plt.plot(iters, losses, label="Train")
  plt.xlabel("Iterations")
  plt.ylabel("Loss")
  plt.show()

  plt.title("Training Curve")
  plt.plot(iters, train_acc, label="Train")
  plt.plot(iters, valid_acc, label="Validation")
  plt.xlabel("Iterations")
  plt.ylabel("Training Accuracy")
  plt.legend(loc='best')
  plt.show()

  print("Final Training Accuracy: {}".format(train_acc[-1]))
  print("Final Validation Accuracy: {}".format(valid_acc[-1]))

# %%
model = SLR()
if torch.cuda.is_available():
    model.cuda()
    print("train on GPU...")

train(model,train_set_features,valid_set_features, batch_size=32, learning_rate=0.001, num_epochs=100)
# Out:
# train on GPU...
# Loading data...
# Starting training...
# Iter number  0  train accuracy:  0.10149023638232271  valid accuracy:  0.09690721649484536
# Iter number  10  train accuracy:  0.11279547790339157  valid accuracy:  0.12371134020618557
# Iter number  20  train accuracy:  0.11253854059609456  valid accuracy:  0.10721649484536082
# Iter number  30  train accuracy:  0.13129496402877697  valid accuracy:  0.13814432989690723
# Iter number  40  train accuracy:  0.14362795477903392  valid accuracy:  0.12989690721649486
# Iter number  50  train accuracy:  0.13206577595066804  valid accuracy:  0.12371134020618557
# Iter number  60  train accuracy:  0.13540596094552929  valid accuracy:  0.1402061855670103
# Iter number  70  train accuracy:  0.1485097636176773  valid accuracy:  0.14845360824742268
# Iter number  80  train accuracy:  0.14028776978417265  valid accuracy:  0.12783505154639174
# Iter number  90  train accuracy:  0.17317574511819117  valid accuracy:  0.1422680412371134
# Iter number  100  train accuracy:  0.17600205549845838  valid accuracy:  0.12164948453608247
# Iter number  110  train accuracy:  0.18627954779033915  valid accuracy:  0.14845360824742268
# Iter number  120  train accuracy:  0.1685508735868448  valid accuracy:  0.13402061855670103
# epoch:  0
# Iter number  130  train accuracy:  0.16521068859198357  valid accuracy:  0.12577319587628866
# Iter number  140  train accuracy:  0.17908530318602262  valid accuracy:  0.1154639175257732
# Iter number  150  train accuracy:  0.20811921891058582  valid accuracy:  0.13195876288659794
# Iter number  160  train accuracy:  0.18088386433710174  valid accuracy:  0.16082474226804125
# Iter number  170  train accuracy:  0.18319630010277493  valid accuracy:  0.15051546391752577
# Iter number  180  train accuracy:  0.21274409044193218  valid accuracy:  0.1670103092783505
# Iter number  190  train accuracy:  0.2147995889003083  valid accuracy:  0.1670103092783505
# Iter number  200  train accuracy:  0.22918807810894143  valid accuracy:  0.15257731958762888
# Iter number  210  train accuracy:  0.20554984583761562  valid accuracy:  0.15257731958762888
# Iter number  220  train accuracy:  0.21891058581706063  valid accuracy:  0.17938144329896907
# Iter number  230  train accuracy:  0.23484069886947584  valid accuracy:  0.17525773195876287
# Iter number  240  train accuracy:  0.2315005138746146  valid accuracy:  0.1979381443298969
# epoch:  1
# Iter number  250  train accuracy:  0.2340698869475848  valid accuracy:  0.18350515463917524
# Iter number  260  train accuracy:  0.2286742034943474  valid accuracy:  0.17525773195876287
# Iter number  270  train accuracy:  0.2317574511819116  valid accuracy:  0.1731958762886598
# Iter number  280  train accuracy:  0.249743062692703  valid accuracy:  0.19381443298969073
# Iter number  290  train accuracy:  0.26104830421377184  valid accuracy:  0.19175257731958764
# Iter number  300  train accuracy:  0.2474306269270298  valid accuracy:  0.18556701030927836
# Iter number  310  train accuracy:  0.2607913669064748  valid accuracy:  0.18350515463917524
# Iter number  320  train accuracy:  0.24845837615621788  valid accuracy:  0.18350515463917524
# Iter number  330  train accuracy:  0.25770811921891057  valid accuracy:  0.2
# Iter number  340  train accuracy:  0.24306269270298048  valid accuracy:  0.15876288659793814
# Iter number  350  train accuracy:  0.2613052415210689  valid accuracy:  0.1979381443298969
# Iter number  360  train accuracy:  0.2885405960945529  valid accuracy:  0.22268041237113403
# epoch:  2
# Iter number  370  train accuracy:  0.2869989722507708  valid accuracy:  0.21649484536082475
# Iter number  380  train accuracy:  0.2864850976361768  valid accuracy:  0.19175257731958764
# Iter number  390  train accuracy:  0.2816032887975334  valid accuracy:  0.2288659793814433
# Iter number  400  train accuracy:  0.2926515930113052  valid accuracy:  0.20824742268041238
# Iter number  410  train accuracy:  0.30421377183967113  valid accuracy:  0.20618556701030927
# Iter number  420  train accuracy:  0.30447070914696817  valid accuracy:  0.20412371134020618
# Iter number  430  train accuracy:  0.2880267214799589  valid accuracy:  0.18969072164948453
# Iter number  440  train accuracy:  0.30472764645426514  valid accuracy:  0.17938144329896907
# Iter number  450  train accuracy:  0.3170606372045221  valid accuracy:  0.2536082474226804
# Iter number  460  train accuracy:  0.328365878725591  valid accuracy:  0.21855670103092784
# Iter number  470  train accuracy:  0.3368448098663926  valid accuracy:  0.20824742268041238
# Iter number  480  train accuracy:  0.31500513874614594  valid accuracy:  0.2597938144329897
# epoch:  3
# Iter number  490  train accuracy:  0.32939362795477906  valid accuracy:  0.1979381443298969
# Iter number  500  train accuracy:  0.3237410071942446  valid accuracy:  0.24948453608247423
# Iter number  510  train accuracy:  0.3183453237410072  valid accuracy:  0.21855670103092784
# Iter number  520  train accuracy:  0.3345323741007194  valid accuracy:  0.2329896907216495
# Iter number  530  train accuracy:  0.34635149023638234  valid accuracy:  0.26804123711340205
# Iter number  540  train accuracy:  0.3540596094552929  valid accuracy:  0.2618556701030928
# Iter number  550  train accuracy:  0.36099691675231244  valid accuracy:  0.2329896907216495
# Iter number  560  train accuracy:  0.3489208633093525  valid accuracy:  0.2536082474226804
# Iter number  570  train accuracy:  0.34917780061664955  valid accuracy:  0.24123711340206186
# Iter number  580  train accuracy:  0.34455292908530316  valid accuracy:  0.2309278350515464
# Iter number  590  train accuracy:  0.3579136690647482  valid accuracy:  0.21443298969072164
# Iter number  600  train accuracy:  0.36613566289825283  valid accuracy:  0.24123711340206186
# epoch:  4
# Iter number  610  train accuracy:  0.3545734840698869  valid accuracy:  0.21443298969072164
# Iter number  620  train accuracy:  0.36228160328879755  valid accuracy:  0.25773195876288657
# Iter number  630  train accuracy:  0.37538540596094555  valid accuracy:  0.2020618556701031
# Iter number  640  train accuracy:  0.34789311408016443  valid accuracy:  0.23711340206185566
# Iter number  650  train accuracy:  0.39568345323741005  valid accuracy:  0.24123711340206186
# Iter number  660  train accuracy:  0.37461459403905445  valid accuracy:  0.24536082474226803
# Iter number  670  train accuracy:  0.3522610483042138  valid accuracy:  0.2309278350515464
# Iter number  680  train accuracy:  0.3545734840698869  valid accuracy:  0.21237113402061855
# Iter number  690  train accuracy:  0.3725590955806783  valid accuracy:  0.24329896907216494
# Iter number  700  train accuracy:  0.3933710174717369  valid accuracy:  0.2309278350515464
# Iter number  710  train accuracy:  0.3936279547790339  valid accuracy:  0.27010309278350514
# Iter number  720  train accuracy:  0.3926002055498458  valid accuracy:  0.26597938144329897
# Iter number  730  train accuracy:  0.40210688591983557  valid accuracy:  0.2309278350515464
# epoch:  5
# Iter number  740  train accuracy:  0.3936279547790339  valid accuracy:  0.2515463917525773
# Iter number  750  train accuracy:  0.3931140801644399  valid accuracy:  0.2536082474226804
# Iter number  760  train accuracy:  0.4103288797533402  valid accuracy:  0.26804123711340205
# Iter number  770  train accuracy:  0.4010791366906475  valid accuracy:  0.24536082474226803
# Iter number  780  train accuracy:  0.37589928057553956  valid accuracy:  0.22474226804123712
# Iter number  790  train accuracy:  0.4193216855087359  valid accuracy:  0.2536082474226804
# Iter number  800  train accuracy:  0.40544707091469684  valid accuracy:  0.26804123711340205
# Iter number  810  train accuracy:  0.40750256937307294  valid accuracy:  0.27010309278350514
# Iter number  820  train accuracy:  0.4172661870503597  valid accuracy:  0.26804123711340205
# Iter number  830  train accuracy:  0.4260020554984584  valid accuracy:  0.2639175257731959
# Iter number  840  train accuracy:  0.4311408016443988  valid accuracy:  0.2597938144329897
# Iter number  850  train accuracy:  0.43782117163412126  valid accuracy:  0.22268041237113403
# epoch:  6
# Iter number  860  train accuracy:  0.44116135662898254  valid accuracy:  0.2329896907216495
# Iter number  870  train accuracy:  0.4226618705035971  valid accuracy:  0.26804123711340205
# Iter number  880  train accuracy:  0.42574511819116134  valid accuracy:  0.2721649484536082
# Iter number  890  train accuracy:  0.41495375128468653  valid accuracy:  0.26804123711340205
# Iter number  900  train accuracy:  0.4329393627954779  valid accuracy:  0.2721649484536082
# Iter number  910  train accuracy:  0.42754367934224047  valid accuracy:  0.26804123711340205
# Iter number  920  train accuracy:  0.4010791366906475  valid accuracy:  0.27422680412371137
# Iter number  930  train accuracy:  0.43499486125385406  valid accuracy:  0.21443298969072164
# Iter number  940  train accuracy:  0.4380781089414183  valid accuracy:  0.24948453608247423
# Iter number  950  train accuracy:  0.44064748201438847  valid accuracy:  0.23505154639175257
# Iter number  960  train accuracy:  0.4511819116135663  valid accuracy:  0.25773195876288657
# Iter number  970  train accuracy:  0.434224049331963  valid accuracy:  0.2515463917525773
# epoch:  7
# Iter number  980  train accuracy:  0.4642857142857143  valid accuracy:  0.26597938144329897
# Iter number  990  train accuracy:  0.46120246659815006  valid accuracy:  0.2824742268041237
# Iter number  1000  train accuracy:  0.4524665981500514  valid accuracy:  0.2288659793814433
# Iter number  1010  train accuracy:  0.4573484069886948  valid accuracy:  0.2536082474226804
# Iter number  1020  train accuracy:  0.45477903391572455  valid accuracy:  0.2865979381443299
# Iter number  1030  train accuracy:  0.4683967112024666  valid accuracy:  0.2865979381443299
# Iter number  1040  train accuracy:  0.46274409044193215  valid accuracy:  0.2721649484536082
# Iter number  1050  train accuracy:  0.460431654676259  valid accuracy:  0.27835051546391754
# Iter number  1060  train accuracy:  0.44809866392600206  valid accuracy:  0.27628865979381445
# Iter number  1070  train accuracy:  0.48741007194244607  valid accuracy:  0.2536082474226804
# Iter number  1080  train accuracy:  0.46736896197327854  valid accuracy:  0.29690721649484536
# Iter number  1090  train accuracy:  0.5043679342240494  valid accuracy:  0.27628865979381445
# epoch:  8
# Iter number  1100  train accuracy:  0.4437307297019527  valid accuracy:  0.27628865979381445
# Iter number  1110  train accuracy:  0.4763617677286742  valid accuracy:  0.24536082474226803
# Iter number  1120  train accuracy:  0.4845837615621788  valid accuracy:  0.2824742268041237
# Iter number  1130  train accuracy:  0.4712230215827338  valid accuracy:  0.24948453608247423
# Iter number  1140  train accuracy:  0.4653134635149024  valid accuracy:  0.2845360824742268
# Iter number  1150  train accuracy:  0.486896197327852  valid accuracy:  0.2639175257731959
# Iter number  1160  train accuracy:  0.45195272353545735  valid accuracy:  0.26804123711340205
# Iter number  1170  train accuracy:  0.4843268242548818  valid accuracy:  0.24948453608247423
# Iter number  1180  train accuracy:  0.47456320657759504  valid accuracy:  0.2907216494845361
# Iter number  1190  train accuracy:  0.4619732785200411  valid accuracy:  0.27422680412371137
# Iter number  1200  train accuracy:  0.4943473792394656  valid accuracy:  0.2618556701030928
# Iter number  1210  train accuracy:  0.49640287769784175  valid accuracy:  0.22268041237113403
# epoch:  9
# Iter number  1220  train accuracy:  0.46120246659815006  valid accuracy:  0.2597938144329897
# Iter number  1230  train accuracy:  0.49922918807810895  valid accuracy:  0.2721649484536082
# Iter number  1240  train accuracy:  0.48381294964028776  valid accuracy:  0.2907216494845361
# Iter number  1250  train accuracy:  0.5092497430626927  valid accuracy:  0.26597938144329897
# Iter number  1260  train accuracy:  0.48895169578622816  valid accuracy:  0.2845360824742268
# Iter number  1270  train accuracy:  0.5015416238437821  valid accuracy:  0.2721649484536082
# Iter number  1280  train accuracy:  0.48766700924974304  valid accuracy:  0.24329896907216494
# Iter number  1290  train accuracy:  0.5241521068859198  valid accuracy:  0.25773195876288657
# Iter number  1300  train accuracy:  0.5305755395683454  valid accuracy:  0.27010309278350514
# Iter number  1310  train accuracy:  0.5089928057553957  valid accuracy:  0.2804123711340206
# Iter number  1320  train accuracy:  0.500256937307297  valid accuracy:  0.26597938144329897
# Iter number  1330  train accuracy:  0.5300616649537513  valid accuracy:  0.26804123711340205
# Iter number  1340  train accuracy:  0.5231243576567317  valid accuracy:  0.27835051546391754
# epoch:  10
# Iter number  1350  train accuracy:  0.5092497430626927  valid accuracy:  0.2721649484536082
# Iter number  1360  train accuracy:  0.5179856115107914  valid accuracy:  0.27628865979381445
# Iter number  1370  train accuracy:  0.5233812949640287  valid accuracy:  0.29896907216494845
# Iter number  1380  train accuracy:  0.5274922918807811  valid accuracy:  0.2721649484536082
# Iter number  1390  train accuracy:  0.5087358684480987  valid accuracy:  0.2639175257731959
# Iter number  1400  train accuracy:  0.524922918807811  valid accuracy:  0.2721649484536082
# Iter number  1410  train accuracy:  0.5161870503597122  valid accuracy:  0.27628865979381445
# Iter number  1420  train accuracy:  0.5326310380267215  valid accuracy:  0.2515463917525773
# Iter number  1430  train accuracy:  0.5341726618705036  valid accuracy:  0.2268041237113402
# Iter number  1440  train accuracy:  0.513103802672148  valid accuracy:  0.24123711340206186
# Iter number  1450  train accuracy:  0.4961459403905447  valid accuracy:  0.25773195876288657
# Iter number  1460  train accuracy:  0.5431654676258992  valid accuracy:  0.2618556701030928
# epoch:  11
# Iter number  1470  train accuracy:  0.5372559095580678  valid accuracy:  0.24123711340206186
# Iter number  1480  train accuracy:  0.5421377183967112  valid accuracy:  0.2515463917525773
# Iter number  1490  train accuracy:  0.5488180883864338  valid accuracy:  0.27628865979381445
# Iter number  1500  train accuracy:  0.5480472764645427  valid accuracy:  0.2824742268041237
# Iter number  1510  train accuracy:  0.5246659815005139  valid accuracy:  0.26804123711340205
# Iter number  1520  train accuracy:  0.5369989722507709  valid accuracy:  0.24742268041237114
# Iter number  1530  train accuracy:  0.5069373072970196  valid accuracy:  0.24329896907216494
# Iter number  1540  train accuracy:  0.5352004110996916  valid accuracy:  0.2536082474226804
# Iter number  1550  train accuracy:  0.5413669064748201  valid accuracy:  0.2515463917525773
# Iter number  1560  train accuracy:  0.5354573484069887  valid accuracy:  0.24948453608247423
# Iter number  1570  train accuracy:  0.5339157245632066  valid accuracy:  0.2597938144329897
# Iter number  1580  train accuracy:  0.5169578622816033  valid accuracy:  0.2804123711340206
# epoch:  12
# Iter number  1590  train accuracy:  0.5280061664953751  valid accuracy:  0.2618556701030928
# Iter number  1600  train accuracy:  0.5508735868448099  valid accuracy:  0.27835051546391754
# Iter number  1610  train accuracy:  0.5488180883864338  valid accuracy:  0.27422680412371137
# Iter number  1620  train accuracy:  0.5701438848920863  valid accuracy:  0.29896907216494845
# Iter number  1630  train accuracy:  0.5737410071942446  valid accuracy:  0.2865979381443299
# Iter number  1640  train accuracy:  0.5557553956834532  valid accuracy:  0.27835051546391754
# Iter number  1650  train accuracy:  0.5151593011305241  valid accuracy:  0.2639175257731959
# Iter number  1660  train accuracy:  0.5318602261048304  valid accuracy:  0.28865979381443296
# Iter number  1670  train accuracy:  0.5619218910585817  valid accuracy:  0.26597938144329897
# Iter number  1680  train accuracy:  0.5572970195272353  valid accuracy:  0.27835051546391754
# Iter number  1690  train accuracy:  0.5169578622816033  valid accuracy:  0.22268041237113403
# Iter number  1700  train accuracy:  0.5041109969167523  valid accuracy:  0.2639175257731959
# epoch:  13
# Iter number  1710  train accuracy:  0.5447070914696814  valid accuracy:  0.22061855670103092
# Iter number  1720  train accuracy:  0.5698869475847893  valid accuracy:  0.24742268041237114
# Iter number  1730  train accuracy:  0.552672147995889  valid accuracy:  0.25773195876288657
# Iter number  1740  train accuracy:  0.5536998972250771  valid accuracy:  0.24329896907216494
# Iter number  1750  train accuracy:  0.5616649537512847  valid accuracy:  0.2618556701030928
# Iter number  1760  train accuracy:  0.5817060637204522  valid accuracy:  0.27628865979381445
# Iter number  1770  train accuracy:  0.5757965056526207  valid accuracy:  0.2515463917525773
# Iter number  1780  train accuracy:  0.5868448098663926  valid accuracy:  0.2515463917525773
# Iter number  1790  train accuracy:  0.5950668036998972  valid accuracy:  0.25773195876288657
# Iter number  1800  train accuracy:  0.5853031860226104  valid accuracy:  0.26804123711340205
# Iter number  1810  train accuracy:  0.5747687564234327  valid accuracy:  0.2824742268041237
# Iter number  1820  train accuracy:  0.567060637204522  valid accuracy:  0.2329896907216495
# epoch:  14
# Iter number  1830  train accuracy:  0.5650051387461459  valid accuracy:  0.2597938144329897
# Iter number  1840  train accuracy:  0.591726618705036  valid accuracy:  0.2288659793814433
# Iter number  1850  train accuracy:  0.5467625899280576  valid accuracy:  0.24123711340206186
# Iter number  1860  train accuracy:  0.5832476875642343  valid accuracy:  0.27010309278350514
# Iter number  1870  train accuracy:  0.5739979445015416  valid accuracy:  0.2556701030927835
# Iter number  1880  train accuracy:  0.5876156217882836  valid accuracy:  0.2639175257731959
# Iter number  1890  train accuracy:  0.5680883864337102  valid accuracy:  0.2536082474226804
# Iter number  1900  train accuracy:  0.5799075025693731  valid accuracy:  0.26804123711340205
# Iter number  1910  train accuracy:  0.5390544707091469  valid accuracy:  0.25773195876288657
# Iter number  1920  train accuracy:  0.579136690647482  valid accuracy:  0.2556701030927835
# Iter number  1930  train accuracy:  0.5686022610483042  valid accuracy:  0.2515463917525773
# Iter number  1940  train accuracy:  0.5770811921891058  valid accuracy:  0.26804123711340205
# Iter number  1950  train accuracy:  0.5817060637204522  valid accuracy:  0.24948453608247423
# epoch:  15
# Iter number  1960  train accuracy:  0.5801644398766701  valid accuracy:  0.2515463917525773
# Iter number  1970  train accuracy:  0.605601233299075  valid accuracy:  0.2721649484536082
# Iter number  1980  train accuracy:  0.6068859198355602  valid accuracy:  0.2865979381443299
# Iter number  1990  train accuracy:  0.5950668036998972  valid accuracy:  0.2597938144329897
# Iter number  2000  train accuracy:  0.6020041109969168  valid accuracy:  0.2639175257731959
# Iter number  2010  train accuracy:  0.5981500513874615  valid accuracy:  0.25773195876288657
# Iter number  2020  train accuracy:  0.5835046248715313  valid accuracy:  0.23917525773195877
# Iter number  2030  train accuracy:  0.5817060637204522  valid accuracy:  0.2329896907216495
# Iter number  2040  train accuracy:  0.6030318602261048  valid accuracy:  0.23711340206185566
# Iter number  2050  train accuracy:  0.5996916752312436  valid accuracy:  0.2824742268041237
# Iter number  2060  train accuracy:  0.6153648509763617  valid accuracy:  0.2804123711340206
# Iter number  2070  train accuracy:  0.5876156217882836  valid accuracy:  0.27010309278350514
# epoch:  16
# Iter number  2080  train accuracy:  0.5845323741007195  valid accuracy:  0.2329896907216495
# Iter number  2090  train accuracy:  0.6014902363823227  valid accuracy:  0.24123711340206186
# Iter number  2100  train accuracy:  0.6127954779033916  valid accuracy:  0.2556701030927835
# Iter number  2110  train accuracy:  0.5937821171634121  valid accuracy:  0.2597938144329897
# Iter number  2120  train accuracy:  0.579136690647482  valid accuracy:  0.23711340206185566
# Iter number  2130  train accuracy:  0.5981500513874615  valid accuracy:  0.23711340206185566
# Iter number  2140  train accuracy:  0.591983556012333  valid accuracy:  0.2804123711340206
# Iter number  2150  train accuracy:  0.6166495375128469  valid accuracy:  0.24742268041237114
# Iter number  2160  train accuracy:  0.6040596094552929  valid accuracy:  0.24742268041237114
# Iter number  2170  train accuracy:  0.5883864337101747  valid accuracy:  0.2329896907216495
# Iter number  2180  train accuracy:  0.6084275436793423  valid accuracy:  0.2845360824742268
# Iter number  2190  train accuracy:  0.6246145940390545  valid accuracy:  0.27628865979381445
# epoch:  17
# Iter number  2200  train accuracy:  0.6207605344295992  valid accuracy:  0.26804123711340205
# Iter number  2210  train accuracy:  0.6148509763617678  valid accuracy:  0.27835051546391754
# Iter number  2220  train accuracy:  0.5845323741007195  valid accuracy:  0.24948453608247423
# Iter number  2230  train accuracy:  0.5886433710174718  valid accuracy:  0.26804123711340205
# Iter number  2240  train accuracy:  0.619475847893114  valid accuracy:  0.2845360824742268
# Iter number  2250  train accuracy:  0.6135662898252826  valid accuracy:  0.2824742268041237
# Iter number  2260  train accuracy:  0.6346351490236383  valid accuracy:  0.24742268041237114
# Iter number  2270  train accuracy:  0.6230729701952723  valid accuracy:  0.2536082474226804
# Iter number  2280  train accuracy:  0.6292394655704008  valid accuracy:  0.27010309278350514
# Iter number  2290  train accuracy:  0.6153648509763617  valid accuracy:  0.2927835051546392
# Iter number  2300  train accuracy:  0.6238437821171634  valid accuracy:  0.24123711340206186
# Iter number  2310  train accuracy:  0.5811921891058581  valid accuracy:  0.2329896907216495
# epoch:  18
# Iter number  2320  train accuracy:  0.605601233299075  valid accuracy:  0.23711340206185566
# Iter number  2330  train accuracy:  0.6212744090441932  valid accuracy:  0.27835051546391754
# Iter number  2340  train accuracy:  0.6449126413155191  valid accuracy:  0.24329896907216494
# Iter number  2350  train accuracy:  0.6050873586844809  valid accuracy:  0.25773195876288657
# Iter number  2360  train accuracy:  0.6266700924974307  valid accuracy:  0.23505154639175257
# Iter number  2370  train accuracy:  0.632065775950668  valid accuracy:  0.2618556701030928
# Iter number  2380  train accuracy:  0.6266700924974307  valid accuracy:  0.23917525773195877
# Iter number  2390  train accuracy:  0.631808838643371  valid accuracy:  0.24742268041237114
# Iter number  2400  train accuracy:  0.6426002055498459  valid accuracy:  0.24329896907216494
# Iter number  2410  train accuracy:  0.6415724563206577  valid accuracy:  0.21855670103092784
# Iter number  2420  train accuracy:  0.6228160328879754  valid accuracy:  0.24948453608247423
# Iter number  2430  train accuracy:  0.6426002055498459  valid accuracy:  0.23711340206185566
# epoch:  19
# Iter number  2440  train accuracy:  0.6531346351490236  valid accuracy:  0.2721649484536082
# Iter number  2450  train accuracy:  0.6210174717368961  valid accuracy:  0.2721649484536082
# Iter number  2460  train accuracy:  0.6109969167523125  valid accuracy:  0.27422680412371137
# Iter number  2470  train accuracy:  0.6392600205549845  valid accuracy:  0.2597938144329897
# Iter number  2480  train accuracy:  0.6523638232271326  valid accuracy:  0.2597938144329897
# Iter number  2490  train accuracy:  0.6328365878725591  valid accuracy:  0.23917525773195877
# Iter number  2500  train accuracy:  0.6248715313463515  valid accuracy:  0.23505154639175257
# Iter number  2510  train accuracy:  0.6189619732785201  valid accuracy:  0.2597938144329897
# Iter number  2520  train accuracy:  0.6377183967112025  valid accuracy:  0.2721649484536082
# Iter number  2530  train accuracy:  0.5976361767728674  valid accuracy:  0.2556701030927835
# Iter number  2540  train accuracy:  0.6243576567317575  valid accuracy:  0.2556701030927835
# Iter number  2550  train accuracy:  0.6392600205549845  valid accuracy:  0.2536082474226804
# Iter number  2560  train accuracy:  0.6346351490236383  valid accuracy:  0.2907216494845361
# epoch:  20
# Iter number  2570  train accuracy:  0.6276978417266187  valid accuracy:  0.2515463917525773
# Iter number  2580  train accuracy:  0.5945529290853032  valid accuracy:  0.27628865979381445
# Iter number  2590  train accuracy:  0.6017471736896197  valid accuracy:  0.2309278350515464
# Iter number  2600  train accuracy:  0.6595580678314491  valid accuracy:  0.2721649484536082
# Iter number  2610  train accuracy:  0.670863309352518  valid accuracy:  0.27835051546391754
# Iter number  2620  train accuracy:  0.6724049331963001  valid accuracy:  0.27628865979381445
# Iter number  2630  train accuracy:  0.6122816032887975  valid accuracy:  0.2288659793814433
# Iter number  2640  train accuracy:  0.6251284686536485  valid accuracy:  0.2597938144329897
# Iter number  2650  train accuracy:  0.6289825282631039  valid accuracy:  0.2721649484536082
# Iter number  2660  train accuracy:  0.6333504624871531  valid accuracy:  0.30103092783505153
# Iter number  2670  train accuracy:  0.6654676258992805  valid accuracy:  0.27422680412371137
# Iter number  2680  train accuracy:  0.6634121274409044  valid accuracy:  0.2721649484536082
# epoch:  21
# Iter number  2690  train accuracy:  0.6551901336073997  valid accuracy:  0.27422680412371137
# Iter number  2700  train accuracy:  0.64568345323741  valid accuracy:  0.2556701030927835
# Iter number  2710  train accuracy:  0.6587872559095581  valid accuracy:  0.2515463917525773
# Iter number  2720  train accuracy:  0.656988694758479  valid accuracy:  0.2804123711340206
# Iter number  2730  train accuracy:  0.6664953751284687  valid accuracy:  0.2618556701030928
# Iter number  2740  train accuracy:  0.6346351490236383  valid accuracy:  0.23505154639175257
# Iter number  2750  train accuracy:  0.6310380267214799  valid accuracy:  0.23711340206185566
# Iter number  2760  train accuracy:  0.6523638232271326  valid accuracy:  0.2597938144329897
# Iter number  2770  train accuracy:  0.6528776978417267  valid accuracy:  0.2515463917525773
# Iter number  2780  train accuracy:  0.6757451181911613  valid accuracy:  0.27010309278350514
# Iter number  2790  train accuracy:  0.6762589928057554  valid accuracy:  0.27628865979381445
# Iter number  2800  train accuracy:  0.6626413155190134  valid accuracy:  0.27010309278350514
# epoch:  22
# Iter number  2810  train accuracy:  0.6610996916752312  valid accuracy:  0.24948453608247423
# Iter number  2820  train accuracy:  0.6649537512846866  valid accuracy:  0.2845360824742268
# Iter number  2830  train accuracy:  0.6533915724563206  valid accuracy:  0.24948453608247423
# Iter number  2840  train accuracy:  0.6688078108941419  valid accuracy:  0.2618556701030928
# Iter number  2850  train accuracy:  0.6860226104830421  valid accuracy:  0.2556701030927835
# Iter number  2860  train accuracy:  0.6736896197327852  valid accuracy:  0.26804123711340205
# Iter number  2870  train accuracy:  0.6469681397738952  valid accuracy:  0.2721649484536082
# Iter number  2880  train accuracy:  0.6652106885919835  valid accuracy:  0.2515463917525773
# Iter number  2890  train accuracy:  0.6564748201438849  valid accuracy:  0.2515463917525773
# Iter number  2900  train accuracy:  0.6585303186022611  valid accuracy:  0.24329896907216494
# Iter number  2910  train accuracy:  0.6598150051387461  valid accuracy:  0.23917525773195877
# Iter number  2920  train accuracy:  0.6551901336073997  valid accuracy:  0.2639175257731959
# epoch:  23
# Iter number  2930  train accuracy:  0.631808838643371  valid accuracy:  0.24329896907216494
# Iter number  2940  train accuracy:  0.6217882836587872  valid accuracy:  0.2288659793814433
# Iter number  2950  train accuracy:  0.645169578622816  valid accuracy:  0.26597938144329897
# Iter number  2960  train accuracy:  0.6849948612538541  valid accuracy:  0.25773195876288657
# Iter number  2970  train accuracy:  0.6469681397738952  valid accuracy:  0.26804123711340205
# Iter number  2980  train accuracy:  0.6575025693730729  valid accuracy:  0.2721649484536082
# Iter number  2990  train accuracy:  0.6688078108941419  valid accuracy:  0.24329896907216494
# Iter number  3000  train accuracy:  0.6438848920863309  valid accuracy:  0.2556701030927835
# Iter number  3010  train accuracy:  0.658273381294964  valid accuracy:  0.2639175257731959
# Iter number  3020  train accuracy:  0.6700924974306269  valid accuracy:  0.27010309278350514
# Iter number  3030  train accuracy:  0.6824254881808839  valid accuracy:  0.2597938144329897
# Iter number  3040  train accuracy:  0.6636690647482014  valid accuracy:  0.27010309278350514
# epoch:  24
# Iter number  3050  train accuracy:  0.6384892086330936  valid accuracy:  0.2288659793814433
# Iter number  3060  train accuracy:  0.6724049331963001  valid accuracy:  0.23917525773195877
# Iter number  3070  train accuracy:  0.6793422404933196  valid accuracy:  0.27010309278350514
# Iter number  3080  train accuracy:  0.644141829393628  valid accuracy:  0.24948453608247423
# Iter number  3090  train accuracy:  0.6698355601233299  valid accuracy:  0.27628865979381445
# Iter number  3100  train accuracy:  0.683967112024666  valid accuracy:  0.2845360824742268
# Iter number  3110  train accuracy:  0.671377183967112  valid accuracy:  0.2556701030927835
# Iter number  3120  train accuracy:  0.6757451181911613  valid accuracy:  0.27835051546391754
# Iter number  3130  train accuracy:  0.6644398766700925  valid accuracy:  0.27010309278350514
# Iter number  3140  train accuracy:  0.6770298047276464  valid accuracy:  0.24948453608247423
# Iter number  3150  train accuracy:  0.6785714285714286  valid accuracy:  0.26804123711340205
# Iter number  3160  train accuracy:  0.6945015416238438  valid accuracy:  0.28865979381443296
# Iter number  3170  train accuracy:  0.7004110996916753  valid accuracy:  0.23917525773195877
# epoch:  25
# Iter number  3180  train accuracy:  0.6695786228160329  valid accuracy:  0.24948453608247423
# Iter number  3190  train accuracy:  0.6937307297019527  valid accuracy:  0.24536082474226803
# Iter number  3200  train accuracy:  0.684224049331963  valid accuracy:  0.22268041237113403
# Iter number  3210  train accuracy:  0.6875642343268242  valid accuracy:  0.2536082474226804
# Iter number  3220  train accuracy:  0.6783144912641316  valid accuracy:  0.2907216494845361
# Iter number  3230  train accuracy:  0.6927029804727647  valid accuracy:  0.27835051546391754
# Iter number  3240  train accuracy:  0.6608427543679343  valid accuracy:  0.2515463917525773
# Iter number  3250  train accuracy:  0.6955292908530318  valid accuracy:  0.2515463917525773
# Iter number  3260  train accuracy:  0.684224049331963  valid accuracy:  0.26804123711340205
# Iter number  3270  train accuracy:  0.6960431654676259  valid accuracy:  0.2804123711340206
# Iter number  3280  train accuracy:  0.6521068859198356  valid accuracy:  0.2536082474226804
# Iter number  3290  train accuracy:  0.6865364850976362  valid accuracy:  0.2865979381443299
# epoch:  26
# Iter number  3300  train accuracy:  0.6911613566289825  valid accuracy:  0.26597938144329897
# Iter number  3310  train accuracy:  0.6885919835560124  valid accuracy:  0.2865979381443299
# Iter number  3320  train accuracy:  0.6878211716341213  valid accuracy:  0.27010309278350514
# Iter number  3330  train accuracy:  0.6919321685508736  valid accuracy:  0.25773195876288657
# Iter number  3340  train accuracy:  0.6934737923946557  valid accuracy:  0.24329896907216494
# Iter number  3350  train accuracy:  0.6772867420349434  valid accuracy:  0.2845360824742268
# Iter number  3360  train accuracy:  0.6783144912641316  valid accuracy:  0.27010309278350514
# Iter number  3370  train accuracy:  0.6772867420349434  valid accuracy:  0.2329896907216495
# Iter number  3380  train accuracy:  0.6641829393627955  valid accuracy:  0.2824742268041237
# Iter number  3390  train accuracy:  0.6605858170606372  valid accuracy:  0.2639175257731959
# Iter number  3400  train accuracy:  0.6503083247687564  valid accuracy:  0.21443298969072164
# Iter number  3410  train accuracy:  0.6747173689619733  valid accuracy:  0.23711340206185566
# epoch:  27
# Iter number  3420  train accuracy:  0.6896197327852004  valid accuracy:  0.2268041237113402
# Iter number  3430  train accuracy:  0.6675231243576567  valid accuracy:  0.23711340206185566
# Iter number  3440  train accuracy:  0.6672661870503597  valid accuracy:  0.2536082474226804
# Iter number  3450  train accuracy:  0.6849948612538541  valid accuracy:  0.24742268041237114
# Iter number  3460  train accuracy:  0.6806269270298048  valid accuracy:  0.24329896907216494
# Iter number  3470  train accuracy:  0.7001541623843782  valid accuracy:  0.22474226804123712
# Iter number  3480  train accuracy:  0.6693216855087358  valid accuracy:  0.2556701030927835
# Iter number  3490  train accuracy:  0.6826824254881809  valid accuracy:  0.2536082474226804
# Iter number  3500  train accuracy:  0.7068345323741008  valid accuracy:  0.26804123711340205
# Iter number  3510  train accuracy:  0.6857656731757451  valid accuracy:  0.24742268041237114
# Iter number  3520  train accuracy:  0.69655704008222  valid accuracy:  0.23917525773195877
# Iter number  3530  train accuracy:  0.6819116135662898  valid accuracy:  0.24329896907216494
# epoch:  28
# Iter number  3540  train accuracy:  0.6765159301130524  valid accuracy:  0.25773195876288657
# Iter number  3550  train accuracy:  0.6986125385405961  valid accuracy:  0.24123711340206186
# Iter number  3560  train accuracy:  0.6906474820143885  valid accuracy:  0.2721649484536082
# Iter number  3570  train accuracy:  0.6855087358684481  valid accuracy:  0.2556701030927835
# Iter number  3580  train accuracy:  0.6909044193216856  valid accuracy:  0.2597938144329897
# Iter number  3590  train accuracy:  0.7019527235354573  valid accuracy:  0.2597938144329897
# Iter number  3600  train accuracy:  0.6955292908530318  valid accuracy:  0.27628865979381445
# Iter number  3610  train accuracy:  0.7029804727646455  valid accuracy:  0.2309278350515464
# Iter number  3620  train accuracy:  0.6834532374100719  valid accuracy:  0.25773195876288657
# Iter number  3630  train accuracy:  0.7024665981500514  valid accuracy:  0.24329896907216494
# Iter number  3640  train accuracy:  0.6865364850976362  valid accuracy:  0.2948453608247423
# Iter number  3650  train accuracy:  0.6598150051387461  valid accuracy:  0.2824742268041237
# epoch:  29
# Iter number  3660  train accuracy:  0.6955292908530318  valid accuracy:  0.2597938144329897
# Iter number  3670  train accuracy:  0.7052929085303186  valid accuracy:  0.24948453608247423
# Iter number  3680  train accuracy:  0.6860226104830421  valid accuracy:  0.23711340206185566
# Iter number  3690  train accuracy:  0.7004110996916753  valid accuracy:  0.2845360824742268
# Iter number  3700  train accuracy:  0.6901336073997945  valid accuracy:  0.24123711340206186
# Iter number  3710  train accuracy:  0.7042651593011305  valid accuracy:  0.2639175257731959
# Iter number  3720  train accuracy:  0.6909044193216856  valid accuracy:  0.22061855670103092
# Iter number  3730  train accuracy:  0.7232785200411099  valid accuracy:  0.24742268041237114
# Iter number  3740  train accuracy:  0.6988694758478932  valid accuracy:  0.2618556701030928
# Iter number  3750  train accuracy:  0.7155704008221994  valid accuracy:  0.2536082474226804
# Iter number  3760  train accuracy:  0.7168550873586845  valid accuracy:  0.26597938144329897
# Iter number  3770  train accuracy:  0.7135149023638232  valid accuracy:  0.24536082474226803
# Iter number  3780  train accuracy:  0.710431654676259  valid accuracy:  0.2556701030927835
# epoch:  30
# Iter number  3790  train accuracy:  0.6947584789311408  valid accuracy:  0.2556701030927835
# Iter number  3800  train accuracy:  0.7040082219938335  valid accuracy:  0.26804123711340205
# Iter number  3810  train accuracy:  0.6726618705035972  valid accuracy:  0.2309278350515464
# Iter number  3820  train accuracy:  0.7014388489208633  valid accuracy:  0.2268041237113402
# Iter number  3830  train accuracy:  0.6942446043165468  valid accuracy:  0.2907216494845361
# Iter number  3840  train accuracy:  0.7022096608427544  valid accuracy:  0.24742268041237114
# Iter number  3850  train accuracy:  0.7050359712230215  valid accuracy:  0.2824742268041237
# Iter number  3860  train accuracy:  0.725077081192189  valid accuracy:  0.2515463917525773
# Iter number  3870  train accuracy:  0.7317574511819116  valid accuracy:  0.2556701030927835
# Iter number  3880  train accuracy:  0.7078622816032888  valid accuracy:  0.24329896907216494
# Iter number  3890  train accuracy:  0.7294450154162384  valid accuracy:  0.24536082474226803
# Iter number  3900  train accuracy:  0.7045220966084276  valid accuracy:  0.2597938144329897
# epoch:  31
# Iter number  3910  train accuracy:  0.6875642343268242  valid accuracy:  0.2639175257731959
# Iter number  3920  train accuracy:  0.7132579650565262  valid accuracy:  0.26804123711340205
# Iter number  3930  train accuracy:  0.6875642343268242  valid accuracy:  0.23505154639175257
# Iter number  3940  train accuracy:  0.7279033915724563  valid accuracy:  0.25773195876288657
# Iter number  3950  train accuracy:  0.7217368961973278  valid accuracy:  0.2721649484536082
# Iter number  3960  train accuracy:  0.7201952723535457  valid accuracy:  0.26597938144329897
# Iter number  3970  train accuracy:  0.6934737923946557  valid accuracy:  0.2721649484536082
# Iter number  3980  train accuracy:  0.722764645426516  valid accuracy:  0.23711340206185566
# Iter number  3990  train accuracy:  0.7322713257965057  valid accuracy:  0.24948453608247423
# Iter number  4000  train accuracy:  0.7217368961973278  valid accuracy:  0.24536082474226803
# Iter number  4010  train accuracy:  0.6901336073997945  valid accuracy:  0.24329896907216494
# Iter number  4020  train accuracy:  0.7207091469681398  valid accuracy:  0.27422680412371137
# epoch:  32
# Iter number  4030  train accuracy:  0.7217368961973278  valid accuracy:  0.27628865979381445
# Iter number  4040  train accuracy:  0.7165981500513875  valid accuracy:  0.24536082474226803
# Iter number  4050  train accuracy:  0.7271325796505652  valid accuracy:  0.2845360824742268
# Iter number  4060  train accuracy:  0.710431654676259  valid accuracy:  0.22474226804123712
# Iter number  4070  train accuracy:  0.7299588900308325  valid accuracy:  0.2639175257731959
# Iter number  4080  train accuracy:  0.6857656731757451  valid accuracy:  0.2597938144329897
# Iter number  4090  train accuracy:  0.6937307297019527  valid accuracy:  0.23505154639175257
# Iter number  4100  train accuracy:  0.6991264131551901  valid accuracy:  0.21649484536082475
# Iter number  4110  train accuracy:  0.7322713257965057  valid accuracy:  0.2268041237113402
# Iter number  4120  train accuracy:  0.7402363823227133  valid accuracy:  0.2721649484536082
# Iter number  4130  train accuracy:  0.7068345323741008  valid accuracy:  0.2309278350515464
# Iter number  4140  train accuracy:  0.7297019527235354  valid accuracy:  0.24742268041237114
# epoch:  33
# Iter number  4150  train accuracy:  0.7176258992805755  valid accuracy:  0.2536082474226804
# Iter number  4160  train accuracy:  0.7389516957862282  valid accuracy:  0.2556701030927835
# Iter number  4170  train accuracy:  0.7153134635149023  valid accuracy:  0.2536082474226804
# Iter number  4180  train accuracy:  0.7327852004110997  valid accuracy:  0.24329896907216494
# Iter number  4190  train accuracy:  0.7309866392600206  valid accuracy:  0.22474226804123712
# Iter number  4200  train accuracy:  0.7456320657759506  valid accuracy:  0.2597938144329897
# Iter number  4210  train accuracy:  0.7160842754367934  valid accuracy:  0.26804123711340205
# Iter number  4220  train accuracy:  0.7122302158273381  valid accuracy:  0.27835051546391754
# Iter number  4230  train accuracy:  0.7219938335046249  valid accuracy:  0.24742268041237114
# Iter number  4240  train accuracy:  0.737153134635149  valid accuracy:  0.2536082474226804
# Iter number  4250  train accuracy:  0.7443473792394656  valid accuracy:  0.27010309278350514
# Iter number  4260  train accuracy:  0.7297019527235354  valid accuracy:  0.2639175257731959
# epoch:  34
# Iter number  4270  train accuracy:  0.7543679342240494  valid accuracy:  0.24123711340206186
# Iter number  4280  train accuracy:  0.7253340184994861  valid accuracy:  0.26597938144329897
# Iter number  4290  train accuracy:  0.7525693730729702  valid accuracy:  0.27010309278350514
# Iter number  4300  train accuracy:  0.7255909558067831  valid accuracy:  0.2329896907216495
# Iter number  4310  train accuracy:  0.724049331963001  valid accuracy:  0.2639175257731959
# Iter number  4320  train accuracy:  0.7294450154162384  valid accuracy:  0.24123711340206186
# Iter number  4330  train accuracy:  0.7379239465570401  valid accuracy:  0.27422680412371137
# Iter number  4340  train accuracy:  0.7433196300102775  valid accuracy:  0.2618556701030928
# Iter number  4350  train accuracy:  0.7340698869475848  valid accuracy:  0.2536082474226804
# Iter number  4360  train accuracy:  0.7322713257965057  valid accuracy:  0.2721649484536082
# Iter number  4370  train accuracy:  0.7119732785200411  valid accuracy:  0.21649484536082475
# Iter number  4380  train accuracy:  0.7232785200411099  valid accuracy:  0.2639175257731959
# Iter number  4390  train accuracy:  0.7124871531346352  valid accuracy:  0.2536082474226804
# epoch:  35
# Iter number  4400  train accuracy:  0.7045220966084276  valid accuracy:  0.2618556701030928
# Iter number  4410  train accuracy:  0.7353545734840699  valid accuracy:  0.24742268041237114
# Iter number  4420  train accuracy:  0.7379239465570401  valid accuracy:  0.2515463917525773
# Iter number  4430  train accuracy:  0.7746659815005139  valid accuracy:  0.2845360824742268
# Iter number  4440  train accuracy:  0.7574511819116135  valid accuracy:  0.2618556701030928
# Iter number  4450  train accuracy:  0.7564234326824255  valid accuracy:  0.2536082474226804
# Iter number  4460  train accuracy:  0.7348406988694759  valid accuracy:  0.27010309278350514
# Iter number  4470  train accuracy:  0.7343268242548818  valid accuracy:  0.2515463917525773
# Iter number  4480  train accuracy:  0.7458890030832477  valid accuracy:  0.27628865979381445
# Iter number  4490  train accuracy:  0.7564234326824255  valid accuracy:  0.2288659793814433
# Iter number  4500  train accuracy:  0.7651593011305241  valid accuracy:  0.2618556701030928
# Iter number  4510  train accuracy:  0.7484583761562179  valid accuracy:  0.2515463917525773
# epoch:  36
# Iter number  4520  train accuracy:  0.7535971223021583  valid accuracy:  0.26597938144329897
# Iter number  4530  train accuracy:  0.7386947584789312  valid accuracy:  0.2515463917525773
# Iter number  4540  train accuracy:  0.7322713257965057  valid accuracy:  0.24329896907216494
# Iter number  4550  train accuracy:  0.7430626927029804  valid accuracy:  0.23917525773195877
# Iter number  4560  train accuracy:  0.7225077081192189  valid accuracy:  0.23711340206185566
# Iter number  4570  train accuracy:  0.7268756423432683  valid accuracy:  0.2536082474226804
# Iter number  4580  train accuracy:  0.7494861253854059  valid accuracy:  0.24742268041237114
# Iter number  4590  train accuracy:  0.7440904419321686  valid accuracy:  0.24742268041237114
# Iter number  4600  train accuracy:  0.7438335046248715  valid accuracy:  0.27628865979381445
# Iter number  4610  train accuracy:  0.7433196300102775  valid accuracy:  0.2556701030927835
# Iter number  4620  train accuracy:  0.7620760534429599  valid accuracy:  0.27628865979381445
# Iter number  4630  train accuracy:  0.7533401849948612  valid accuracy:  0.24329896907216494
# epoch:  37
# Iter number  4640  train accuracy:  0.7358684480986639  valid accuracy:  0.23505154639175257
# Iter number  4650  train accuracy:  0.7577081192189106  valid accuracy:  0.2597938144329897
# Iter number  4660  train accuracy:  0.7127440904419322  valid accuracy:  0.24329896907216494
# Iter number  4670  train accuracy:  0.7173689619732785  valid accuracy:  0.23917525773195877
# Iter number  4680  train accuracy:  0.751027749229188  valid accuracy:  0.24536082474226803
# Iter number  4690  train accuracy:  0.7561664953751285  valid accuracy:  0.2556701030927835
# Iter number  4700  train accuracy:  0.7507708119218911  valid accuracy:  0.2721649484536082
# Iter number  4710  train accuracy:  0.7255909558067831  valid accuracy:  0.24329896907216494
# Iter number  4720  train accuracy:  0.7461459403905447  valid accuracy:  0.2597938144329897
# Iter number  4730  train accuracy:  0.7512846865364851  valid accuracy:  0.26597938144329897
# Iter number  4740  train accuracy:  0.7525693730729702  valid accuracy:  0.2556701030927835
# Iter number  4750  train accuracy:  0.7571942446043165  valid accuracy:  0.27422680412371137
# epoch:  38
# Iter number  4760  train accuracy:  0.737410071942446  valid accuracy:  0.2597938144329897
# Iter number  4770  train accuracy:  0.7384378211716341  valid accuracy:  0.28865979381443296
# Iter number  4780  train accuracy:  0.7577081192189106  valid accuracy:  0.2618556701030928
# Iter number  4790  train accuracy:  0.722764645426516  valid accuracy:  0.2618556701030928
# Iter number  4800  train accuracy:  0.737410071942446  valid accuracy:  0.24742268041237114
# Iter number  4810  train accuracy:  0.7512846865364851  valid accuracy:  0.27010309278350514
# Iter number  4820  train accuracy:  0.7494861253854059  valid accuracy:  0.24948453608247423
# Iter number  4830  train accuracy:  0.737667009249743  valid accuracy:  0.21855670103092784
# Iter number  4840  train accuracy:  0.7338129496402878  valid accuracy:  0.27010309278350514
# Iter number  4850  train accuracy:  0.7533401849948612  valid accuracy:  0.27010309278350514
# Iter number  4860  train accuracy:  0.7482014388489209  valid accuracy:  0.26804123711340205
# Iter number  4870  train accuracy:  0.7546248715313464  valid accuracy:  0.2556701030927835
# epoch:  39
# Iter number  4880  train accuracy:  0.7643884892086331  valid accuracy:  0.24329896907216494
# Iter number  4890  train accuracy:  0.7541109969167523  valid accuracy:  0.26804123711340205
# Iter number  4900  train accuracy:  0.7528263103802673  valid accuracy:  0.27422680412371137
# Iter number  4910  train accuracy:  0.7379239465570401  valid accuracy:  0.2268041237113402
# Iter number  4920  train accuracy:  0.775950668036999  valid accuracy:  0.2639175257731959
# Iter number  4930  train accuracy:  0.7720966084275437  valid accuracy:  0.27422680412371137
# Iter number  4940  train accuracy:  0.7643884892086331  valid accuracy:  0.2639175257731959
# Iter number  4950  train accuracy:  0.7453751284686536  valid accuracy:  0.27422680412371137
# Iter number  4960  train accuracy:  0.7173689619732785  valid accuracy:  0.26804123711340205
# Iter number  4970  train accuracy:  0.7281603288797533  valid accuracy:  0.2721649484536082
# Iter number  4980  train accuracy:  0.7322713257965057  valid accuracy:  0.26804123711340205
# Iter number  4990  train accuracy:  0.725077081192189  valid accuracy:  0.26804123711340205
# Iter number  5000  train accuracy:  0.7335560123329907  valid accuracy:  0.2824742268041237
# epoch:  40
# Iter number  5010  train accuracy:  0.7515416238437821  valid accuracy:  0.2824742268041237
# Iter number  5020  train accuracy:  0.7428057553956835  valid accuracy:  0.23505154639175257
# Iter number  5030  train accuracy:  0.7345837615621789  valid accuracy:  0.2597938144329897
# Iter number  5040  train accuracy:  0.7605344295991778  valid accuracy:  0.24742268041237114
# Iter number  5050  train accuracy:  0.7546248715313464  valid accuracy:  0.2639175257731959
# Iter number  5060  train accuracy:  0.7330421377183967  valid accuracy:  0.23917525773195877
# Iter number  5070  train accuracy:  0.7579650565262076  valid accuracy:  0.2927835051546392
# Iter number  5080  train accuracy:  0.7595066803699897  valid accuracy:  0.26597938144329897
# Iter number  5090  train accuracy:  0.7613052415210688  valid accuracy:  0.24536082474226803
# Iter number  5100  train accuracy:  0.7708119218910586  valid accuracy:  0.24536082474226803
# Iter number  5110  train accuracy:  0.7566803699897225  valid accuracy:  0.2515463917525773
# Iter number  5120  train accuracy:  0.7777492291880781  valid accuracy:  0.24742268041237114
# epoch:  41
# Iter number  5130  train accuracy:  0.7669578622816033  valid accuracy:  0.24948453608247423
# ...
# Iter number  8200  train accuracy:  0.7641315519013361  valid accuracy:  0.2309278350515464
# Iter number  8210  train accuracy:  0.7697841726618705  valid accuracy:  0.22268041237113403
# Iter number  8220  train accuracy:  0.7998458376156218  valid accuracy:  0.23917525773195877
# Iter number  8230  train accuracy:  0.7967625899280576  valid accuracy:  0.23711340206185566
# Iter number  8240  train accuracy:  0.8221993833504625  valid accuracy:  0.2515463917525773
# Iter number  8250  train accuracy:  0.8052415210688592  valid accuracy:  0.24948453608247423
# Iter number  8260  train accuracy:  0.7882836587872559  valid accuracy:  0.24329896907216494
# Iter number  8270  train accuracy:  0.8219424460431655  valid accuracy:  0.30103092783505153
# Iter number  8280  train accuracy:  0.8376156217882836  valid accuracy:  0.2329896907216495
# Iter number  8290  train accuracy:  0.8173175745118191  valid accuracy:  0.2268041237113402
# epoch:  67
# Iter number  8300  train accuracy:  0.789825282631038  valid accuracy:  0.23711340206185566
# Iter number  8310  train accuracy:  0.7836587872559095  valid accuracy:  0.25773195876288657
# Iter number  8320  train accuracy:  0.8062692702980473  valid accuracy:  0.2288659793814433
# Iter number  8330  train accuracy:  0.7952209660842754  valid accuracy:  0.24948453608247423
# Iter number  8340  train accuracy:  0.7785200411099692  valid accuracy:  0.2639175257731959
# Iter number  8350  train accuracy:  0.8193730729701952  valid accuracy:  0.2597938144329897
# Iter number  8360  train accuracy:  0.7923946557040082  valid accuracy:  0.24123711340206186
# Iter number  8370  train accuracy:  0.8196300102774923  valid accuracy:  0.24329896907216494
# Iter number  8380  train accuracy:  0.8093525179856115  valid accuracy:  0.2865979381443299
# Iter number  8390  train accuracy:  0.8332476875642343  valid accuracy:  0.2556701030927835
# Iter number  8400  train accuracy:  0.7993319630010277  valid accuracy:  0.2515463917525773
# Iter number  8410  train accuracy:  0.814748201438849  valid accuracy:  0.2536082474226804
# epoch:  68
# Iter number  8420  train accuracy:  0.8013874614594039  valid accuracy:  0.2639175257731959
# Iter number  8430  train accuracy:  0.8301644398766701  valid accuracy:  0.2556701030927835
# Iter number  8440  train accuracy:  0.8054984583761562  valid accuracy:  0.26597938144329897
# Iter number  8450  train accuracy:  0.8450668036998972  valid accuracy:  0.2721649484536082
# Iter number  8460  train accuracy:  0.8216855087358684  valid accuracy:  0.26804123711340205
# Iter number  8470  train accuracy:  0.7944501541623844  valid accuracy:  0.24948453608247423
# Iter number  8480  train accuracy:  0.8196300102774923  valid accuracy:  0.2597938144329897
# Iter number  8490  train accuracy:  0.8306783144912642  valid accuracy:  0.24123711340206186
# Iter number  8500  train accuracy:  0.8180883864337102  valid accuracy:  0.27422680412371137
# Iter number  8510  train accuracy:  0.814748201438849  valid accuracy:  0.28865979381443296
# Iter number  8520  train accuracy:  0.8180883864337102  valid accuracy:  0.2618556701030928
# Iter number  8530  train accuracy:  0.8186022610483042  valid accuracy:  0.2556701030927835
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Hao Xiang Yang\UofT Courses\2. Winter 2022\APS360\Project\APS360-Project\trainModel.ipynb Cell 6' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Hao%20Xiang%20Yang/UofT%20Courses/2.%20Winter%202022/APS360/Project/APS360-Project/trainModel.ipynb#ch0000005?line=2'>3</a>     model.cuda()
#       <a href='vscode-notebook-cell:/c%3A/Hao%20Xiang%20Yang/UofT%20Courses/2.%20Winter%202022/APS360/Project/APS360-Project/trainModel.ipynb#ch0000005?line=3'>4</a>     print("train on GPU...")
# ----> <a href='vscode-notebook-cell:/c%3A/Hao%20Xiang%20Yang/UofT%20Courses/2.%20Winter%202022/APS360/Project/APS360-Project/trainModel.ipynb#ch0000005?line=5'>6</a> train(model,train_set_features,valid_set_features, batch_size=32, learning_rate=0.001, num_epochs=100)
#
# c:\Hao Xiang Yang\UofT Courses\2. Winter 2022\APS360\Project\APS360-Project\trainModel.ipynb Cell 5' in train(model, train_set, valid_set, batch_size, learning_rate, beta1, beta2, eps, num_epochs)
#      <a href='vscode-notebook-cell:/c%3A/Hao%20Xiang%20Yang/UofT%20Courses/2.%20Winter%202022/APS360/Project/APS360-Project/trainModel.ipynb#ch0000004?line=32'>33</a> losses.append(float(loss)/batch_size) #compute "average" loss
#      <a href='vscode-notebook-cell:/c%3A/Hao%20Xiang%20Yang/UofT%20Courses/2.%20Winter%202022/APS360/Project/APS360-Project/trainModel.ipynb#ch0000004?line=33'>34</a> train_acc.append(get_accuracy(model,train_loader,valid_loader,train=True))
# ---> <a href='vscode-notebook-cell:/c%3A/Hao%20Xiang%20Yang/UofT%20Courses/2.%20Winter%202022/APS360/Project/APS360-Project/trainModel.ipynb#ch0000004?line=34'>35</a> valid_acc.append(get_accuracy(model,train_loader,valid_loader,train=False))
#      <a href='vscode-notebook-cell:/c%3A/Hao%20Xiang%20Yang/UofT%20Courses/2.%20Winter%202022/APS360/Project/APS360-Project/trainModel.ipynb#ch0000004?line=35'>36</a> if n%10 == 0:
#      <a href='vscode-notebook-cell:/c%3A/Hao%20Xiang%20Yang/UofT%20Courses/2.%20Winter%202022/APS360/Project/APS360-Project/trainModel.ipynb#ch0000004?line=36'>37</a>   print("Iter number ",n, " train accuracy: ",train_acc[n], " valid accuracy: ",valid_acc[n])
#
# c:\Hao Xiang Yang\UofT Courses\2. Winter 2022\APS360\Project\APS360-Project\trainModel.ipynb Cell 4' in get_accuracy(model, train_loader, valid_loader, train)
#       <a href='vscode-notebook-cell:/c%3A/Hao%20Xiang%20Yang/UofT%20Courses/2.%20Winter%202022/APS360/Project/APS360-Project/trainModel.ipynb#ch0000003?line=7'>8</a> correct = 0
#       <a href='vscode-notebook-cell:/c%3A/Hao%20Xiang%20Yang/UofT%20Courses/2.%20Winter%202022/APS360/Project/APS360-Project/trainModel.ipynb#ch0000003?line=8'>9</a> total = 0
# ---> <a href='vscode-notebook-cell:/c%3A/Hao%20Xiang%20Yang/UofT%20Courses/2.%20Winter%202022/APS360/Project/APS360-Project/trainModel.ipynb#ch0000003?line=9'>10</a> for imgs, labels in data:
#      <a href='vscode-notebook-cell:/c%3A/Hao%20Xiang%20Yang/UofT%20Courses/2.%20Winter%202022/APS360/Project/APS360-Project/trainModel.ipynb#ch0000003?line=10'>11</a>
#      <a href='vscode-notebook-cell:/c%3A/Hao%20Xiang%20Yang/UofT%20Courses/2.%20Winter%202022/APS360/Project/APS360-Project/trainModel.ipynb#ch0000003?line=11'>12</a>     #enable GPU Usage
#      <a href='vscode-notebook-cell:/c%3A/Hao%20Xiang%20Yang/UofT%20Courses/2.%20Winter%202022/APS360/Project/APS360-Project/trainModel.ipynb#ch0000003?line=12'>13</a>     if torch.cuda.is_available():
#      <a href='vscode-notebook-cell:/c%3A/Hao%20Xiang%20Yang/UofT%20Courses/2.%20Winter%202022/APS360/Project/APS360-Project/trainModel.ipynb#ch0000003?line=13'>14</a>       imgs = imgs.cuda()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\dataloader.py:521, in _BaseDataLoaderIter.__next__(self)
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/dataloader.py?line=518'>519</a> if self._sampler_iter is None:
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/dataloader.py?line=519'>520</a>     self._reset()
# --> <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/dataloader.py?line=520'>521</a> data = self._next_data()
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/dataloader.py?line=521'>522</a> self._num_yielded += 1
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/dataloader.py?line=522'>523</a> if self._dataset_kind == _DatasetKind.Iterable and \
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/dataloader.py?line=523'>524</a>         self._IterableDataset_len_called is not None and \
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/dataloader.py?line=524'>525</a>         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\dataloader.py:561, in _SingleProcessDataLoaderIter._next_data(self)
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/dataloader.py?line=558'>559</a> def _next_data(self):
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/dataloader.py?line=559'>560</a>     index = self._next_index()  # may raise StopIteration
# --> <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/dataloader.py?line=560'>561</a>     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/dataloader.py?line=561'>562</a>     if self._pin_memory:
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/dataloader.py?line=562'>563</a>         data = _utils.pin_memory.pin_memory(data)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\_utils\fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/_utils/fetch.py?line=46'>47</a> def fetch(self, possibly_batched_index):
#      <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/_utils/fetch.py?line=47'>48</a>     if self.auto_collation:
# ---> <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/_utils/fetch.py?line=48'>49</a>         data = [self.dataset[idx] for idx in possibly_batched_index]
#      <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/_utils/fetch.py?line=49'>50</a>     else:
#      <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/_utils/fetch.py?line=50'>51</a>         data = self.dataset[possibly_batched_index]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\_utils\fetch.py:49, in <listcomp>(.0)
#      <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/_utils/fetch.py?line=46'>47</a> def fetch(self, possibly_batched_index):
#      <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/_utils/fetch.py?line=47'>48</a>     if self.auto_collation:
# ---> <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/_utils/fetch.py?line=48'>49</a>         data = [self.dataset[idx] for idx in possibly_batched_index]
#      <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/_utils/fetch.py?line=49'>50</a>     else:
#      <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/utils/data/_utils/fetch.py?line=50'>51</a>         data = self.dataset[possibly_batched_index]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\datasets\folder.py:232, in DatasetFolder.__getitem__(self, index)
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torchvision/datasets/folder.py?line=223'>224</a> """
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torchvision/datasets/folder.py?line=224'>225</a> Args:
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torchvision/datasets/folder.py?line=225'>226</a>     index (int): Index
#    (...)
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torchvision/datasets/folder.py?line=228'>229</a>     tuple: (sample, target) where target is class_index of the target class.
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torchvision/datasets/folder.py?line=229'>230</a> """
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torchvision/datasets/folder.py?line=230'>231</a> path, target = self.samples[index]
# --> <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torchvision/datasets/folder.py?line=231'>232</a> sample = self.loader(path)
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torchvision/datasets/folder.py?line=232'>233</a> if self.transform is not None:
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torchvision/datasets/folder.py?line=233'>234</a>     sample = self.transform(sample)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\serialization.py:600, in load(f, map_location, pickle_module, **pickle_load_args)
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/serialization.py?line=594'>595</a> if _is_zipfile(opened_file):
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/serialization.py?line=595'>596</a>     # The zipfile reader is going to advance the current file position.
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/serialization.py?line=596'>597</a>     # If we want to actually tail call to torch.jit.load, we need to
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/serialization.py?line=597'>598</a>     # reset back to the original position.
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/serialization.py?line=598'>599</a>     orig_position = opened_file.tell()
# --> <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/serialization.py?line=599'>600</a>     with _open_zipfile_reader(opened_file) as opened_zipfile:
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/serialization.py?line=600'>601</a>         if _is_torchscript_zip(opened_zipfile):
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/serialization.py?line=601'>602</a>             warnings.warn("'torch.load' received a zip file that looks like a TorchScript archive"
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/serialization.py?line=602'>603</a>                           " dispatching to 'torch.jit.load' (call 'torch.jit.load' directly to"
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/serialization.py?line=603'>604</a>                           " silence this warning)", UserWarning)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\serialization.py:242, in _open_zipfile_reader.__init__(self, name_or_buffer)
#     <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/serialization.py?line=240'>241</a> def __init__(self, name_or_buffer) -> None:
# --> <a href='file:///c%3A/Users/haoxi/AppData/Local/Programs/Python/Python39/lib/site-packages/torch/serialization.py?line=241'>242</a>     super(_open_zipfile_reader, self).__init__(torch._C.PyTorchFileReader(name_or_buffer))
#
# KeyboardInterrupt:
